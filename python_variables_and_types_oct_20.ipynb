# %% [markdown]
# # 🐍 Python для початківців: Типи даних та змінні
# ---
# Цей ноутбук допоможе вам потренуватись у створенні змінних, роботі з базовими типами даних та написанні простих програм у Python.
# Виконуйте завдання послідовно у своїх комірках і звертайте увагу на результати.

# %% [markdown]
# ## Розділ 1. Знайомство зі змінними
# **Мета:** навчитися створювати змінні, присвоювати значення та переглядати типи.
#
# **Завдання 1.** Створи змінні:
# - name — твоє ім’я
# - age — твій вік
# - city — місто, у якому ти живеш
#
# Потім виведи їх на екран.

# %%
name = "Svitlana"
age = 45
city = "Sömmerda"
print(name, age, city)
# Out:
# Svitlana 45 Sömmerda

# %% [markdown]
# **Завдання 2.**
# Додай рядок:

# %%
print("Мене звати", name, "мені", age, "років, я живу в", city)
# Out:
# Мене звати Svitlana мені 45 років, я живу в Sömmerda

# %% [markdown]
# **Завдання 3.** Використай функцію `type()` для кожної змінної та подивись, який у неї тип.

# %%
print(type(name))
print(type(age))
print(type(city))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>

# %% [markdown]
# **Завдання 4.**
# Зміни значення змінної age на нове (наприклад, `age = age + 1`) і виведи нове речення:
# “Наступного року мені буде ... років.”

# %%
age = age + 1
print("Наступного року мені буде ", age, "років")
# Out:
# Наступного року мені буде  46 років

# %% [markdown]
# ## Розділ 2. Основні типи даних
# **Мета:** попрактикуватись із `int`, `float`, `str`, `bool`.
#
# **Завдання 5.**
#
# Створи змінні:
# - a = 10
# - b = 3.5
# - c = "Python"

# %%
a = 10
b = 3.5
c = "Python"
print(a,b,c)
# Out:
# 10 3.5 Python

# %% [markdown]
# **Завдання 6.**
#
# Виконай такі дії та подивись, який буде результат:
# - a + b
# - a / 2
# - a // 2
# - a % 3
# - a ** 3

# %%
print(a + b)
print(a / 2)
print(a // 2)
print(a % 3)
print(a ** 3)
# Out:
# 13.5
# 5.0
# 5
# 1
# 1000

# %% [markdown]
# **Завдання 7.**
# Зміни тип змінної `a` на `str` і об’єднай її з `c`.

# %%
print(str(a) + c)
# Out:
# 10Python

# %% [markdown]
# **Завдання 8.**
# Порівняй різні значення:
# - 5 > 2
# - 7 == 8
# - 10 != 10
# - 3 <= 5

# %%
print(5>2)
print(7 ==8)
print(10 != 10)
print(3 <= 5)
# Out:
# True
# False
# False
# True

# %% [markdown]
# ## Розділ 3. Робота з рядками (`str`)

# %% [markdown]
# **Завдання 9.**
# Створи рядок `text = "Python is fun!"`.

# %%
text = "Python is fun!"

# %% [markdown]
# **Завдання 10.**
#
# Виведи:
# - довжину рядка (len(text))
# - перший і останній символ
# - рядок у верхньому регістрі
# - рядок у нижньому регістрі

# %%
print(len(text))
print(text[1],text[-1])
# Out:
# 14
# y !

# %% [markdown]
# **Завдання 11.**
# Створи речення з кількох змінних:
# ```
# lang = "Python"
# level = "beginner"
# print(f"I am a {level} in {lang}")
# ```

# %%
level = "beginner"
lang = "Python"
print(f"I am a {level} in {lang}")
# Out:
# I am a beginner in Python

# %% [markdown]
# **Завдання 12.**
# Попроси користувача ввести своє ім’я через input() і виведи:
# `print("Привіт,", name + "!")`

# %%
name = input("Enter name: ")

print("Привіт,", name + "!" )
# Out:
# Привіт! Svitlana!

# %% [markdown]
# ## Розділ 4. Робота з числами

# %% [markdown]
# **Завдання 13.**
# Обчисли площу прямокутника:
# - створи змінні `a = 5, b = 8`
# - знайди `area = a * b`
# - виведи результат: "Площа прямокутника дорівнює ..."

# %%
a = 5
b = 8
print("Площя трикутника дорівнює: ", a * 2 + b * 2, "cm")
# Out:
# Площя трикутника дорівнює:  26 cm

# %% [markdown]
# **Завдання 14.**
# Обчисли середнє арифметичне трьох чисел, введених користувачем.

# %%
a = float(input("Enter number 1 "))
в = float(input("Enter number 2 "))
c = float(input("Enter number 3 "))
print("Середнє арифметичне значення трьох чисел складає: ", ((a+b+c)/3))
# Out:
# Середнє арифметичне значення трьох чисел складає:  5.333333333333333

# %% [markdown]
# **Завдання 15.**
# Створи змінну `temperature_c = 25` і переведи її у Фаренгейти:
#
# `temperature_f = temperature_c * 9/5 + 32`

# %%
temperature_c = 25
temperatyre_f = temperature_c * 9 / 5 + 32
print(temperatyre_f)
# Out:
# 77.0

# %% [markdown]
# ## Розділ 5. Логічні вирази (`bool`)

# %% [markdown]
# **Завдання 16.**
# Перевір, чи людина повнолітня:
# ```
# age = int(input("Скільки тобі років? "))
# is_adult = age >= 18
# print("Повнолітній?", is_adult)

# %%
age = int(input("Скільки тобі років?"))
is_adult = age >= 18
print("Повнолітній?",is_adult)
# Out:
# Повнолітній? True

# %% [markdown]
# **Завдання 17.**
# Напиши перевірку парності:
# ```
# number = int(input("Введи число: "))
# print("Парне?", number % 2 == 0)

# %%
number = int(input("Введи число: "))
print("Парне?", number % 2 == 0)
# Out:
# Парне? True

# %% [markdown]
# **Завдання 18.**
# Створи дві змінні x = 10, y = 20.
# Виведи результат:
# - `x > 5 and y < 30`
# - `x < 0 or y == 20`
# - `not(x > y)`

# %%
x = 10
y = 20
print(x > 5 and y < 30)
print(x < 0, y == 20)
print(not(x > y))
# Out:
# True
# False True
# True

# %% [markdown]
# ## Розділ 6. Комбіновані завдання

# %% [markdown]
# **Завдання 19.**
# Попроси користувача ввести рік народження та обчисли вік.
# Потім виведи:
# ```
# "Твій вік: ... років"
# "Повнолітній? True/False"

# %%
biryear = int(input("Введи свій рік народження: "))
print("Твій вік: ", 2025-biryear, "років")
print("Повнолітній?", biryear >= 18)
print(f"Твій вік: {2025-biryear}")
print(f"Повнолітній?, {biryear >= 18}")
# Out:
# Твій вік:  45 років
# Повнолітній? True
# Твій вік: 45
# Повнолітній?, True

# %% [markdown]
# **Завдання 20.**
# Створи калькулятор, який:
# - запитує два числа і дію (+, -, *, /)
# - виводить результат обчислення.

# %%
a = float(input("Введи число a: "))
b = float(input("Введи число b: "))
math_sign = str(input("Введи один з наступник математичних знаків +, -, *, ,: "))
res = "".join([str(a), math_sign, str(b)])
print(eval(res))
# Out:
# 7.0

# %% [markdown]
# **Завдання 21.**
# Створи просту програму для обчислення індексу маси тіла (BMI):
# ```
# weight = float(input("Введи вагу (кг): "))
# height = float(input("Введи зріст (м): "))
# bmi = weight / (height ** 2)
# print("Твій індекс маси тіла:", bmi)

# %%
weight = float(input("Введи вагу (кг): "))
height = float(input("Введи вагу (м): "))
bmi = weight / (height ** 2)
print("Tвій ітдекс маси тіла: ", bmi)

# %% [markdown]
# **Завдання 22.**
# Створи змінну `sentence = "learning python is easy and fun"`
#
# 1. перетвори першу літеру у велику `(capitalize())`
# 2. порахуй, скільки разів зустрічається літера "a"
# 3. перевір, чи рядок містить слово "fun"

# %%
sentence = "learnind python is easy and fun"
sentence.capitalize()
sentence.count("a")
sentence.find("fun")

# %% [markdown]
# **Завдання 23.**
# 🧮 Конвертер валют
# Попроси користувача ввести суму в євро та курс долара.
# Обчисли, скільки це буде в доларах.

# %%
euro = float(input("Введи суму в євро: "))
exchange_rate = float(input("Введи курс до долару: "))
print(f"Сума в доларах склада {euro * exchange_rate}")

# %% [markdown]
# **Завдання 24.**
# 📆 Калькулятор віку
# Введи поточний рік і рік народження користувача.
# Порахуйте, скільки років людині буде через 5 років.

# %%
biryear = int(input("Введи свій рік народження: "))
today_year = int(input("Введи теперішній рік: "))
print(f"Через 5 років тобі буде {today_year - biryear + 5}")

# %% [markdown]
# **Завдання 25.**
# Користувач вводить:
# - ім’я
# - улюблену мову програмування
#
# Якщо це "Python" — вивести "Ти крутий!",
# інакше — "Треба спробувати Python:)"

# %%
name = input("Напиши своє ім'я: ")
language = input("Напиши свою улюблену мову програмування: ")
if language == "Python":
    print(name + "! " + "Ти крутий!")
else:
    print(name + "! " + "Треба спробувати Python)")
# Out:
# svitlana! Ти крутий!
